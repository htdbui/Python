# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Missing Data Handling</h1>
#
# Sure! Here are the remaining functions you requested in the raw format:
#
# __DataFrame.backfill(*[, axis, inplace, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.backfill()
# ```
#
# __DataFrame.bfill(*[, axis, inplace, limit, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.bfill()
# ```
#
# __DataFrame.dropna(*[, axis, how, thresh, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.dropna()
# ```
#
# __DataFrame.ffill(*[, axis, inplace, limit, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.ffill()
# ```
#
# __DataFrame.fillna([value, method, axis, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.fillna(value=0)
# ```
#
# __DataFrame.interpolate([method, axis, limit, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan], 'c': [1, 2, 3]})
# df1.interpolate()
# ```
#
# __DataFrame.isna()__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.isna()
# ```
#
# __DataFrame.isnull()__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.isnull()
# ```
#
# __DataFrame.notna()__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.notna()
# ```
#
# __DataFrame.notnull()__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.notnull()
# ```
#
# __DataFrame.pad(*[, axis, inplace, limit, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, np.nan, 3], 'b': [4, 5, np.nan]})
# df1.pad()
# ```
#
# __DataFrame.replace([to_replace, value, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.replace({2: 22, 3: 33})
# ```
