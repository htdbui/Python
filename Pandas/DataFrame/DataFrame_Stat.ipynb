# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Descriptive Stats</h1>
#
# __DataFrame.abs()__
# ```
# df1 = pd.DataFrame({'a': [-1, 2, -3], 'b': [4, -5, 6]})
# df1.abs()
# ```
#
# __DataFrame.all([axis, bool_only, skipna])__
# ```
# df1 = pd.DataFrame({'a': [True, True, True], 'b': [False, True, False]})
# df1.all()
# ```
#
# __DataFrame.any(*[, axis, bool_only, skipna])__
# ```
# df1 = pd.DataFrame({'a': [True, True, True], 'b': [False, True, False]})
# df1.any()
# ```
#
# __DataFrame.clip([lower, upper, axis, inplace])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.clip(lower=2, upper=5)
# ```
#
# __DataFrame.corr([method, min_periods, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.corr()
# ```
#
# __DataFrame.corrwith(other[, axis, drop, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df2 = pd.DataFrame({'a': [2, 3, 4], 'b': [5, 6, 7]})
# df1.corrwith(df2)
# ```
#
# __DataFrame.count([axis, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, None], 'b': [4, 5, 6]})
# df1.count()
# ```
#
# __DataFrame.cov([min_periods, ddof, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.cov()
# ```
#
# __DataFrame.cummax([axis, skipna])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 3]})
# df1.cummax()
# ```
#
# __DataFrame.cummin([axis, skipna])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 3]})
# df1.cummin()
# ```
#
# __DataFrame.cumprod([axis, skipna])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.cumprod()
# ```
#
# __DataFrame.cumsum([axis, skipna])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.cumsum()
# ```
#
# __DataFrame.describe([percentiles, include, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.describe()
# ```
#
# __DataFrame.diff([periods, axis])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.diff()
# ```
#
# __DataFrame.eval(expr, *[, inplace])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.eval('c = a + b')
# ```
#
# __DataFrame.kurt([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.kurt()
# ```
#
# __DataFrame.kurtosis([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.kurtosis()
# ```
#
# __DataFrame.max([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.max()
# ```
#
# __DataFrame.mean([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.mean()
# ```
#
# __DataFrame.median([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.median()
# ```
#
# __DataFrame.min([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.min()
# ```
#
# __DataFrame.mode([axis, numeric_only, dropna])__
# ```
# df1 = pd.DataFrame({'a': [1, 1, 2], 'b': [3, 3, 4]})
# df1.mode()
# ```
#
# __DataFrame.pct_change([periods, fill_method, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 4], 'b': [4, 5, 6]})
# df1.pct_change()
# ```
#
# __DataFrame.prod([axis, skipna, numeric_only, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.prod()
# ```
#
# __DataFrame.product([axis, skipna, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.product()
# ```
#
# __DataFrame.quantile([q, axis, numeric_only, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.quantile(q=0.5)
# ```
#
# __DataFrame.rank([axis, method, numeric_only, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.rank()
# ```
#
# __DataFrame.round([decimals])__
# ```
# df1 = pd.DataFrame({'a': [1.23456, 2.34567, 3.45678], 'b': [4.56789, 5.67890, 6.78901]})
# df1.round(2)
# ```
#
# __DataFrame.sem([axis, skipna, ddof, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.sem()
# ```
#
# __DataFrame.skew([axis, skipna, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.skew()
# ```
#
# __DataFrame.sum([axis, skipna, numeric_only, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.sum()
# ```
#
# __DataFrame.std([axis, skipna, ddof, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.std()
# ```
#
# __DataFrame.var([axis, skipna, ddof, numeric_only])__
# ```
# df1 = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})
# df1.var()
# ```
#
# __DataFrame.nunique([axis, dropna])__
# ```
# df1 = pd.DataFrame({'a': [1, 1, 2], 'b': [3, 3, 4]})
# df1.nunique()
# ```
#
# __DataFrame.value_counts([subset, normalize, ...])__
# ```
# df1 = pd.DataFrame({'a': [1, 1, 2], 'b': [3, 3, 4]})
# df1['a'].value_counts()
# ```
