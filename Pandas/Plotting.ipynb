# %% [markdown]
# __andrews_curves(frame, class_column[, ax, ...])__
#
# ```
# from pandas.plotting import andrews_curves
#
# iris = pd.read_csv('iris.csv')
# plt.figure()
# andrews_curves(iris, 'species')
# plt.show()
# ```
#
# __autocorrelation_plot(series[, ax])__
#
# ```
# from pandas.plotting import autocorrelation_plot
#
# s = pd.Series([1, 2, 3, 4, 5])
# plt.figure()
# autocorrelation_plot(s)
# plt.show()
# ```
#
# __bootstrap_plot(series[, fig, size, samples])__
#
# ```
# from pandas.plotting import bootstrap_plot
#
# s = pd.Series([1, 2, 3, 4, 5])
# plt.figure()
# bootstrap_plot(s)
# plt.show()
# ```
#
# __boxplot(data[, column, by, ax, fontsize, ...])__
#
# ```
# from pandas.plotting import boxplot
#
# df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': [3, 4, 5, 6]})
# plt.figure()
# boxplot(df)
# plt.show()
# ```
#
# __deregister_matplotlib_converters()__
#
# ```
# from pandas.plotting import deregister_matplotlib_converters
# deregister_matplotlib_converters()
# ```
#
# __lag_plot(series[, lag, ax])__
#
# ```
# from pandas.plotting import lag_plot
#
# s = pd.Series([1, 2, 3, 4, 5])
# plt.figure()
# lag_plot(s)
# plt.show()
# ```
#
#
# __parallel_coordinates(frame, class_column[, ...])__
#
# ```
# from pandas.plotting import parallel_coordinates
#
# iris = pd.read_csv('iris.csv')
# plt.figure()
# parallel_coordinates(iris, 'species')
# plt.show()
# ```
#
# __plot_params__
#
# ```
# from pandas.plotting import plot_params
# plot_params.update({'figure.figsize': (16, 8)})
# ```
#
# __radviz(frame, class_column[, ax, color, ...])__
#
# ```
# from pandas.plotting import radviz
#
# iris = pd.read_csv('iris.csv')
# plt.figure()
# radviz(iris, 'species')
# plt.show()
# ```
#
# __register_matplotlib_converters()__
#
# ```
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()
# ```
#
# __scatter_matrix(frame[, alpha, figsize, ax, ...])__
#
# ```
# from pandas.plotting import scatter_matrix
#
# iris = pd.read_csv('iris.csv')
# plt.figure()
# scatter_matrix(iris, diagonal='kde')
# plt.show()
# ```
#
# __table(ax, data, **kwargs)__
#
# ```
# from pandas.plotting import table
#
# data = [[1, 2], [3, 4]]
# fig, ax = plt.subplots()
# table(ax, data, loc='upper right', colWidths=[0.2, 0.2], cellLoc='center')
# plt.show()
# ```
