# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Flat File</h1>
#
# Sure, here are the requested markdown notebooks for each method without any explanations:
#
# __read_table(filepath_or_buffer, *[, sep, ...])__
#
# ```
# url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv'
#
# pd.read_table(url, sep=',')
# ```
#
# __read_csv(filepath_or_buffer, *[, sep, ...])__
#
# ```
# url = 'https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv'
#
# pd.read_csv(url)
# ```
#
# __DataFrame.to_csv([path_or_buf, sep, na_rep, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# df.to_csv('example.csv', index=False)
# ```
#
# __read_fwf(filepath_or_buffer, *[, colspecs, ...])__
#
# ```
# url = 'https://people.sc.fsu.edu/~jburkardt/data/fwfbv/fwfbv54.txt'
#
# pd.read_fwf(url, colspecs='infer', header=None)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Excel</h1>
#
# __read_excel(io[, sheet_name, header, names, ...])__
#
# ```
# url = 'https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx'
#
# pd.read_excel(url, sheet_name='Sheet1')
# ```
#
# __DataFrame.to_excel(excel_writer[, ...])**kwargs)__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# writer = pd.ExcelWriter('example.xlsx')
#
# df.to_excel(writer, index=False)
#
# writer.save()
# ```
#
# __ExcelFile(path_or_buffer[, engine, ...])__
#
# ```
# url = 'https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx'
#
# excel_file = pd.ExcelFile(url)
#
# excel_file.sheet_names
# ```
#
# __ExcelFile.book__
#
# ```
# url = 'https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx'
#
# excel_file = pd.ExcelFile(url)
#
# excel_file.book
# ```
#
# __ExcelFile.sheet_names__
#
# ```
# url = 'https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx'
#
# excel_file = pd.ExcelFile(url)
#
# excel_file.sheet_names
# ```
#
# __ExcelFile.parse([sheet_name, header, names, ...])__
#
# ```
# url = 'https://github.com/datagy/pivot_table_pandas/raw/master/sample_pivot.xlsx'
#
# excel_file = pd.ExcelFile(url)
#
# excel_file.parse(sheet_name='Sheet1')
# ```
#
# __Styler.to_excel(excel_writer[, sheet_name, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# styled = df.style.highlight_max()
#
# writer = pd.ExcelWriter('example.xlsx')
#
# styled.to_excel(writer, index=False, sheet_name='Sheet1')
#
# writer.save()
# ```
#
# __ExcelWriter(path[, engine, date_format, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# writer = pd.ExcelWriter('example.xlsx')
#
# df.to_excel(writer, index=False)
#
# writer.save()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">HTML</h1>
#
# __read_html(io, *[, match, flavor, header, ...])__
#
# ```
# url = 'https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)'
#
# tables = pd.read_html(url)
#
# tables[0]
# ```
#
# __DataFrame.to_html([buf, columns, col_space, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# df.to_html('example.html', index=False)
# ```
#
# __Styler.to_html([buf, table_uuid, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# styled = df.style.highlight_max()
#
# html = styled.to_html(index=False)
#
# with open('example.html', 'w') as f:
#     f.write(html)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">STATA</h1>
#
# __read_stata(filepath_or_buffer, *[, ...])__
#
# ```
# url = 'https://github.com/PhilChodrow/PIC16B/blob/master/datasets/maketable.dta?raw=true'
#
# pd.read_stata(url)
# ```
#
# __DataFrame.to_stata(path, *[, convert_dates, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# df.to_stata('example.dta', write_index=False)
# ```
#
# __StataReader.data_label__
#
# ```
# url = 'https://github.com/PhilChodrow/PIC16B/blob/master/datasets/maketable.dta?raw=true'
#
# with pd.io.stata.StataReader(url) as reader:
#     print(reader.data_label)
# ```
#
# __StataReader.value_labels()__
#
# ```
# url = 'https://github.com/PhilChodrow/PIC16B/blob/master/datasets/maketable.dta?raw=true'
#
# with pd.io.stata.StataReader(url) as reader:
#     print(reader.value_labels())
# ```
#
# __StataReader.variable_labels()__
#
# ```
# url = 'https://github.com/PhilChodrow/PIC16B/blob/master/datasets/maketable.dta?raw=true'
#
# with pd.io.stata.StataReader(url) as reader:
#     print(reader.variable_labels())
# ```
#
# __StataWriter.write_file()__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# with pd.io.stata.StataWriter('example.dta') as writer:
#     writer.write_file(df)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Latex</h1>
#
# __DataFrame.to_latex([buf, columns, header, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# print(df.to_latex(index=False))
# ```
#
# __Styler.to_latex([buf, column_format, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# styled = df.style.highlight_max()
#
# print(styled.to_latex(index=False))
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">SQL</h1>
#
# __read_sql_table(table_name, con[, schema, ...])__
#
# ```
# import sqlite3
#
# conn = sqlite3.connect('example.db')
#
# pd.read_sql_table('example', conn)
# ```
#
# __read_sql_query(sql, con[, index_col, ...])__
#
# ```
# import sqlite3
#
# conn = sqlite3.connect('example.db')
#
# pd.read_sql_query('SELECT * FROM example', conn)
# ```
#
# __read_sql(sql, con[, index_col, ...])__
#
# ```
# import sqlite3
#
# conn = sqlite3.connect('example.db')
#
# pd.read_sql('SELECT * FROM example', conn)
# ```
#
# __DataFrame.to_sql(name, con[, schema, ...])__
#
# ```
# import sqlite3
#
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# conn = sqlite3.connect('example.db')
#
# df.to_sql('example', conn, index=False, if_exists='replace')
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">XML</h1>
#
# __read_xml(path_or_buffer, *[, xpath, ...])__
#
# ```
# url = 'https://github.com/PhilChodrow/PIC16B/blob/master/datasets/books.xml?raw=true'
#
# pd.read_xml(url, xpath='/catalog/book')
# ```
#
# __DataFrame.to_xml([path_or_buf, ...])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# df.to_xml('example.xml', index=False)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Clipboard</h1>
#
# __read_clipboard([sep, dtype_backend])__
#
# ```
# # Copy a table to clipboard first
# # Then run this cell
#
# pd.read_clipboard()
# ```
#
# __DataFrame.to_clipboard([excel, sep])__
#
# ```
# df = pd.DataFrame({
#     'A': ['foo', 'bar', 'baz'],
#     'B': [1, 2, 3],
#     'C': [4.0, 5.0, 6.0]
# })
#
# df.to_clipboard(index=False)
# ```
