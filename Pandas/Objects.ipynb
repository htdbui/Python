# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Timestamp</h1>
#
# # - Properties
#
#     ts = pd.Timestamp('2022-05-01T12:34:56')
#     ts.asm8
#     ts.day
#     ts.dayofweek
#     ts.day_of_week
#     ts.dayofyear
#     ts.day_of_year
#     ts.days_in_month
#     ts.daysinmonth
#     ts.fold
#     ts.hour
#     ts.is_leap_year
#     ts.is_month_end
#     ts.is_month_start
#     ts.is_quarter_end
#     ts.is_quarter_start
#     ts.is_year_end
#     ts.is_year_start
#     ts.max
#     ts.microsecond
#     ts.min
#     ts.minute
#     ts.month
#     ts.nanosecond
#     ts.quarter
#     ts.resolution
#     ts.second
#     ts.tz
#     ts.tzinfo
#     ts.unit
#     ts.value
#     ts.week
#     ts.weekofyear
#     ts.year
#
# # - Methods
#
# __Timestamp.as_unit__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').as_unit('D')
#
# ```
#
# __Timestamp.astimezone(tz)__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').astimezone('US/Eastern')
#
# ```
#
# __Timestamp.ceil(freq[, ambiguous, nonexistent])__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56.789').ceil('s')
#
# ```
#
# __Timestamp.combine(date, time)__
#
# ```
# ts = pd.Timestamp('2022-05-01T12:34:56')
#
# date = ts.date()
# time = pd.Timedelta(hours=1, minutes=30)
#
# print(ts.combine(date, time))
# ```
#
# __Timestamp.ctime__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').ctime()
# ```
#
# __Timestamp.date__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').date()
# ```
#
# __Timestamp.day_name__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').day_name()
#
# ```
#
# __Timestamp.dst__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').dst()
#
# ```
#
# __Timestamp.floor(freq[, ambiguous, nonexistent])__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56.789').floor('s')
# ```
#
# __Timestamp.fromordinal(ordinal[, tz])__
#
# ```
# pd.Timestamp.fromordinal(737030)
#
# ```
#
# __Timestamp.fromtimestamp(ts)__
#
# ```
# import time
#
# pd.Timestamp.fromtimestamp(time.time())
#
# ```
#
# __Timestamp.isocalendar__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').isocalendar()
#
# ```
#
# __Timestamp.isoformat__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').isoformat()
#
# ```
#
# __Timestamp.isoweekday()__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').isoweekday()
# ```
#
# __Timestamp.month_name__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').month_name()
#
# ```
#
# __Timestamp.normalize__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56.789').normalize()
#
# ```
#
# __Timestamp.now([tz])__
#
# ```
# pd.Timestamp.now()
# ```
#
# __Timestamp.replace([year, month, day, hour, ...])__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').replace(day=2)
#
# ```
#
# __Timestamp.round(freq[, ambiguous, nonexistent])__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56.789').round('s')
#
# ```
#
# __Timestamp.strftime(format)__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').strftime('%Y-%m-%d')
#
# ```
#
# __Timestamp.strptime(string, format)__
#
# ```
# ts_string = '2022-05-01T12:34:56'
# ts_format = '%Y-%m-%dT%H:%M:%S'
#
# pd.Timestamp.strptime(ts_string, ts_format)
# ```
#
# __Timestamp.time__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').time()
#
# ```
#
# __Timestamp.timestamp__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').timestamp()
#
# ```
#
# __Timestamp.timetuple__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').timetuple()
#
# ```
#
# __Timestamp.timetz__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').timetz()
#
# ```
#
# __Timestamp.to_datetime64__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').to_datetime64()
#
# ```
#
# __Timestamp.to_numpy__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').to_numpy()
#
# ```
#
# __Timestamp.to_julian_date()__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').to_julian_date()
#
# ```
#
# __Timestamp.to_period__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').to_period('D')
#
# ```
#
# __Timestamp.to_pydatetime__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').to_pydatetime()
#
# ```
#
# __Timestamp.today([tz])__
#
# ```
# pd.Timestamp.today()
#
# ```
#
# __Timestamp.toordinal__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').toordinal()
#
# ```
#
# __Timestamp.tz_convert(tz)__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').tz_convert('US/Eastern')
#
# ```
#
# __Timestamp.tz_localize(tz[, ambiguous, ...])__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').tz_localize('US/Eastern')
# ```
#
# __Timestamp.tzname__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').tzname()
#
# ```
#
# __Timestamp.utcfromtimestamp(ts)__
#
# ```
# import time
#
# pd.Timestamp.utcfromtimestamp(time.time())
# ```
#
# __Timestamp.utcnow()__
#
# ```
# pd.Timestamp.utcnow()
#
# ```
#
# __Timestamp.utcoffset__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').utcoffset()
#
# ```
#
# __Timestamp.utctimetuple__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').utctimetuple()
#
# ```
#
# __Timestamp.weekday()__
#
# ```
# pd.Timestamp('2022-05-01T12:34:56').weekday()
#
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Timedelta</h1>
#
# # - Properties
#
# __Timedelta.asm8__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').asm8
# ```
#
# __Timedelta.components__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').components
# ```
#
# __Timedelta.days__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').days
# ```
#
# __Timedelta.max__
#
# ```
# td1 = pd.Timedelta('1 days 2 hours 30 minutes 59 seconds')
# td2 = pd.Timedelta('2 days 1 hour 29 minutes 58 seconds')
#
# pd.Timedelta.max(td1, td2).view('int64')
# ```
#
# __Timedelta.microseconds__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').microseconds
# ```
#
# __Timedelta.min__
#
# ```
# td1 = pd.Timedelta('1 days 2 hours 30 minutes 59 seconds')
# td2 = pd.Timedelta('2 days 1 hour 29 minutes 58 seconds')
#
# pd.Timedelta.min(td1, td2).view('int64')
# ```
#
# __Timedelta.nanoseconds__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').nanoseconds
# ```
#
# __Timedelta.resolution__
#
# ```
# pd.Timedelta.resolution.view('int64')
# ```
#
# __Timedelta.seconds__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').seconds
# ```
#
# __Timedelta.unit__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').unit
# ```
#
# __Timedelta.value__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').value
# ```
#
# __Timedelta.view__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').view('int64')
# ```
#
# # - Methods
#
# __Timedelta.as_unit__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').as_unit('s')
# ```
#
# __Timedelta.ceil(freq)__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').ceil('H')
# ```
#
# __Timedelta.floor(freq)__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').floor('H')
# ```
#
# __Timedelta.isoformat__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').isoformat()
# ```
#
# __Timedelta.round(freq)__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').round('H')
# ```
#
# __Timedelta.to_pytimedelta__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').to_pytimedelta()
# ```
#
# __Timedelta.to_timedelta64__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').to_timedelta64()
# ```
#
# __Timedelta.to_numpy__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').to_numpy()
# ```
#
# __Timedelta.total_seconds__
#
# ```
# pd.Timedelta('1 days 2 hours 30 minutes 59 seconds').total_seconds()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Period</h1>
#
# # - Properties
# Sure, here are the requested methods without the `print()` statement:
#
# __Period.day__
#
# ```
# pd.Period('2021-04-07', 'D').day
# ```
#
# __Period.dayofweek__
#
# ```
# pd.Period('2021-04-07', 'D').dayofweek
# ```
#
# __Period.day_of_week__
#
# ```
# pd.Period('2021-04-07', 'D').day_of_week
# ```
#
# __Period.dayofyear__
#
# ```
# pd.Period('2021-04-07', 'D').dayofyear
# ```
#
# __Period.day_of_year__
#
# ```
# pd.Period('2021-04-07', 'D').day_of_year
# ```
#
# __Period.days_in_month__
#
# ```
# pd.Period('2021-04-07', 'M').days_in_month
# ```
#
# __Period.daysinmonth__
#
# ```
# pd.Period('2021-04-07', 'M').daysinmonth
# ```
#
# __Period.end_time__
#
# ```
# pd.Period('2021-04-07', 'D').end_time
# ```
#
# __Period.freq__
#
# ```
# pd.Period('2021-04-07', 'D').freq
# ```
#
# __Period.freqstr__
#
# ```
# pd.Period('2021-04-07', 'D').freqstr
# ```
#
# __Period.hour__
#
# ```
# pd.Period('2021-04-07 12:30:45', 'H').hour
# ```
# Sure, here are the requested methods without the `print()` statement:
#
# __Period.is_leap_year__
#
# ```
# pd.Period('2020-01-01', 'D').is_leap_year
# ```
#
# __Period.minute__
#
# ```
# pd.Period('2021-04-07 12:30:45', 'T').minute
# ```
#
# __Period.month__
#
# ```
# pd.Period('2021-04-07', 'D').month
# ```
#
# __Period.ordinal__
#
# ```
# pd.Period('2021-04-07', 'D').ordinal
# ```
#
# __Period.quarter__
#
# ```
# pd.Period('2021-04-07', 'D').quarter
# ```
#
# __Period.qyear__
#
# ```
# pd.Period('2021-04-07', 'D').qyear
# ```
#
# __Period.second__
#
# ```
# pd.Period('2021-04-07 12:30:45', 'T').second
# ```
#
# __Period.start_time__
#
# ```
# pd.Period('2021-04-07', 'D').start_time
# ```
#
# __Period.week__
#
# ```
# pd.Period('2021-04-07', 'D').week
# ```
#
# __Period.weekday__
#
# ```
# pd.Period('2021-04-07', 'D').weekday
# ```
#
# __Period.weekofyear__
#
# ```
# pd.Period('2021-04-07', 'D').weekofyear
# ```
#
# __Period.year__
#
# ```
# pd.Period('2021-04-07', 'D').year
# ```
# # - Methods
#
# __Period.asfreq__
#
# ```
# pd.Period('2021-04-07', 'D').asfreq('H')
# ```
#
# __Period.now__
#
# ```
# pd.Period.now(freq='H')
# ```
#
# __Period.strftime__
#
# ```
# pd.Period('2021-04-07', 'D').strftime('%Y/%m/%d')
# ```
#
# __Period.to_timestamp__
#
# ```
# pd.Period('2021-04-07', 'D').to_timestamp()
# ```
#
# Please note that the `to_timestamp()` method returns a timestamp object, which may not display properly in some environments.

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Intervals</h1>
#
# # - Properties
#
# __Interval.closed__
#
# ```
# pd.Interval(1, 5).closed
# ```
#
# __Interval.closed_left__
#
# ```
# pd.Interval(1, 5, closed='left').closed_left
# ```
#
# __Interval.closed_right__
#
# ```
# pd.Interval(1, 5, closed='right').closed_right
# ```
#
# __Interval.is_empty__
#
# ```
# pd.Interval(5, 1).is_empty
# ```
#
# __Interval.left__
#
# ```
# pd.Interval(1, 5).left
# ```
#
# __Interval.length__
#
# ```
# pd.Interval(1, 5).length
# ```
#
# __Interval.mid__
#
# ```
# pd.Interval(1, 5).mid
# ```
#
# __Interval.open_left__
#
# ```
# pd.Interval(1, 5, closed='left').open_left
# ```
#
# __Interval.open_right__
#
# ```
# pd.Interval(1, 5, closed='right').open_right
# ```
#
# __Interval.overlaps__
#
# ```
# pd.Interval(1, 5).overlaps(pd.Interval(3, 7))
# ```
#
# __Interval.right__
#
# ```
# pd.Interval(1, 5).right
# ```
# # - Methods

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Categorical</h1>
#
# __Categorical(values[, categories, ordered, ...])__
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange'])
# ```
#
# __Categorical.dtype__
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange']).dtype
# ```
#
# __Categorical.categories__
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange']).categories
# ```
#
# __Categorical.ordered__
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange'], ordered=True).ordered
# ```
#
# __Categorical.codes__
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange']).codes
# ```
#
# __Categorical.__array__**
#
# ```
# pd.Categorical(['apple', 'banana', 'apple', 'orange']).__array__()
# ```
#
# __CategoricalDtype([categories, ordered])__
#
# ```
# pd.CategoricalDtype(['good', 'bad'], ordered=True)
# ```
#
# __CategoricalDtype.categories__
#
# ```
# pd.CategoricalDtype(['good', 'bad'], ordered=True).categories
# ```
#
# __CategoricalDtype.ordered__
#
# ```
# pd.CategoricalDtype(['good', 'bad'], ordered=True).ordered
# ```
#
# __Categorical.from_codes__
#
# ```
# pd.Categorical.from_codes([0, 1, 0, 1], dtype=pd.CategoricalDtype(['good', 'bad'], ordered=True))
# ```
