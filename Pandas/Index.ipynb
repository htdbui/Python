# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Properties</h1>
#
# __Index.values__
#
# ```
# pd.Index(['a', 'b', 'c']).values
# ```
#
# __Index.is_monotonic_increasing__
#
# ```
# pd.Index(['a', 'b', 'c']).is_monotonic_increasing
# ```
#
# __Index.is_monotonic_decreasing__
#
# ```
# pd.Index(['c', 'b', 'a']).is_monotonic_decreasing
# ```
#
# __Index.is_unique__
#
# ```
# pd.Index(['a', 'b', 'c']).is_unique
# ```
#
# __Index.has_duplicates__
#
# ```
# pd.Index(['a', 'b', 'c', 'a']).has_duplicates
# ```
#
# __Index.hasnans__
#
# ```
# pd.Index([1, 2, np.nan]).hasnans
# ```
#
# __Index.dtype__
#
# ```
# pd.Index(['a', 'b', 'c']).dtype
# ```
#
# __Index.inferred_type__
#
# ```
# pd.Index(['a', 'b', 'c']).inferred_type
# ```
#
# __Index.shape__
#
# ```
# pd.Index(['a', 'b', 'c']).shape
# ```
#
# __Index.name__
#
# ```
# pd.Index(['a', 'b', 'c'], name='my_index').name
# ```
#
# __Index.names__
#
# ```
# pd.Index(['a', 'b', 'c'], name='my_index').names
# ```
#
# __Index.nbytes__
#
# ```
# pd.Index(['a', 'b', 'c']).nbytes
# ```
#
# __Index.ndim__
#
# ```
# pd.Index(['a', 'b', 'c']).ndim
# ```
#
# __Index.size__
#
# ```
# pd.Index(['a', 'b', 'c']).size
# ```
#
# __Index.empty__
#
# ```
# pd.Index([]).empty
# ```
#
# __Index.T__
#
# ```
# pd.Index(['a', 'b', 'c']).T
# ```
#
# __Index.memory_usage([deep])__
#
# ```
# pd.Index(['a', 'b', 'c']).memory_usage(deep=True)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Modifying and Computations</h1>
#
# __Index.all(*args, **kwargs)__
#
# ```
# pd.Index([True, False, True]).all()
# ```
#
# __Index.any(*args, **kwargs)__
#
# ```
# pd.Index([True, False, True]).any()
# ```
#
# __Index.argmin([axis, skipna])__
#
# ```
# pd.Index(['a', 'b', 'c']).argmin()
# ```
#
# __Index.argmax([axis, skipna])__
#
# ```
# pd.Index(['a', 'b', 'c']).argmax()
# ```
#
# __Index.copy([name, deep])__
#
# ```
# pd.Index(['a', 'b', 'c']).copy()
# ```
#
# __Index.delete(loc)__
#
# ```
# pd.Index(['a', 'b', 'c']).delete(1)
# ```
#
# __Index.drop(labels[, errors])__
#
# ```
# pd.Index(['a', 'b', 'c']).drop('b')
# ```
#
# __Index.drop_duplicates(*[, keep])__
#
# ```
# pd.Index(['a', 'b', 'c', 'a']).drop_duplicates()
# ```
#
# __Index.duplicated([keep])__
#
# ```
# pd.Index(['a', 'b', 'c', 'a']).duplicated()
# ```
#
# __Index.equals(other)__
#
# ```
# pd.Index(['a', 'b', 'c']).equals(pd.Index(['a', 'b', 'c']))
# ```
#
# __Index.factorize([sort, use_na_sentinel])__
#
# ```
# pd.Index(['a', 'a', 'b']).factorize()
# ```
#
# __Index.identical(other)__
#
# ```
# pd.Index(['a', 'b', 'c']).identical(pd.Index(['a', 'b', 'c']))
# ```
#
# __Index.insert(loc, item)__
#
# ```
# pd.Index(['a', 'b', 'c']).insert(1, 'd')
# ```
#
# __Index.is_(other)__
#
# ```
# pd.Index(['a', 'b', 'c']).is_(pd.Index(['a', 'b', 'c']))
# ```
#
# __Index.is_boolean()__
#
# ```
# pd.Index([True, False, True]).is_boolean()
# ```
#
# __Index.is_categorical()__
#
# ```
# pd.Index(pd.Categorical(['a', 'b', 'a'])).is_categorical()
# ```
#
# __Index.is_floating()__
#
# ```
# pd.Index([1.0, 2.0, 3.0]).is_floating()
# ```
#
# __Index.is_integer()__
#
# ```
# pd.Index([1, 2, 3]).is_integer()
# ```
#
# __Index.is_interval()__
#
# ```
# pd.IntervalIndex.from_breaks([0, 1, 2]).is_interval()
# ```
#
# __Index.is_numeric()__
#
# ```
# pd.Index([1, 2, 3]).is_numeric()
# ```
#
# __Index.is_object()__
#
# ```
# pd.Index(['a', 'b', 'c']).is_object()
# ```
#
# __Index.min([axis, skipna])__
#
# ```
# pd.Index([1, 2, 3]).min()
# ```
#
# __Index.max([axis, skipna])__
#
# ```
# pd.Index([1, 2, 3]).max()
# ```
#
# __Index.reindex(target[, method, level, ...])__
#
# ```
# pd.Index(['a', 'b', 'c']).reindex(['c', 'a'])
# ```
#
# __Index.rename(name[, inplace])__
#
# ```
# pd.Index(['a', 'b', 'c']).rename('my_index')
# ```
#
# __Index.repeat(repeats[, axis])__
#
# ```
# pd.Index(['a', 'b', 'c']).repeat([2, 1, 3])
# ```
#
# __Index.where(cond[, other])__
#
# ```
# pd.Index([1, 2, 3]).where(pd.Index([True, False, True]))
# ```
#
# __Index.take(indices[, axis, allow_fill, ...])__
#
# ```
# pd.Index(['a', 'b', 'c']).take([2, 0])
# ```
#
# __Index.putmask(mask, value)__
#
# ```
# pd.Index(['a', 'b', 'c']).putmask([False, True, False], '_')
# ```
#
# __Index.unique([level])__
#
# ```
# pd.Index(['a', 'b', 'a', 'c']).unique()
# ```
#
# __Index.nunique([dropna])__
#
# ```
# pd.Index(['a', 'b', 'a', 'c']).nunique()
# ```
#
# __Index.value_counts([normalize, sort, ...])__
#
# ```
# pd.Index(['a', 'b', 'a', 'c']).value_counts()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Compatibility with MultiIndex</h1>
#
# __Index.set_names(names, *[, level, inplace])__
#
# ```
# pd.Index(['a', 'b', 'c']).set_names('my_index')
# ```
#
# __Index.droplevel([level])__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (2, 'b'), (3, 'c')]).droplevel(1)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Missing values</h1>
#
# __Index.fillna([value, downcast])__
#
# ```
# pd.Index([1, 2, np.nan]).fillna(0)
# ```
#
# __Index.dropna([how])__
#
# ```
# pd.Index([1, 2, np.nan]).dropna()
# ```
#
# __Index.isna()__
#
# ```
# pd.Index([1, 2, np.nan]).isna()
# ```
#
# __Index.notna()__
#
# ```
# pd.Index([1, 2, np.nan]).notna()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Conversion</h1>
#
# __Index.astype(dtype[, copy])__
#
# ```
# pd.Index(['1', '2', '3']).astype(int)
# ```
#
# __Index.item()__
#
# ```
# pd.Index([1]).item()
# ```
#
# __Index.map(mapper[, na_action])__
#
# ```
# pd.Index(['a', 'b', 'c']).map({'a': 1, 'b': 2, 'c': 3})
# ```
#
# __Index.ravel([order])__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (2, 'b'), (3, 'c')]).ravel()
# ```
#
# __Index.to_list()__
#
# ```
# pd.Index(['a', 'b', 'c']).to_list()
# ```
#
# __Index.to_series([index, name])__
#
# ```
# pd.Index(['a', 'b', 'c']).to_series(name='my_series')
# ```
#
# __Index.to_frame([index, name])__
#
# ```
# pd.Index(['a', 'b', 'c']).to_frame(name='my_frame')
# ```
#
# __Index.view([cls])__
#
# ```
# pd.Index([1, 2, 3]).view(np.int32)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Sorting</h1>
#
# Here are the requested methods in a more compact format using only one line of code:
#
# __Index.argsort(*args, **kwargs)__
#
# ```
# pd.Index(['c', 'a', 'b']).argsort()
# ```
#
# __Index.searchsorted(value[, side, sorter])__
#
# ```
# pd.Index([1, 2, 3]).searchsorted(2.5)
# ```
#
# __Index.sort_values([return_indexer, ...])__
#
# ```
# pd.Index(['c', 'a', 'b']).sort_values()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Time-specific operations</h1>
#
# __Index.shift([periods, freq])__
#
# ```
# pd.Index([1, 2, 3]).shift(1)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Combining / Joining / Set operations</h1>
#
# __Index.append(other)__
#
# ```
# pd.Index(['a', 'b', 'c']).append(pd.Index(['d', 'e', 'f']))
# ```
#
# __Index.join(other, *[, how, level, ...])__
#
# ```
# pd.Index(['a', 'b', 'c']).join(pd.Index(['c', 'd', 'e']))
# ```
#
# __Index.intersection(other[, sort])__
#
# ```
# pd.Index(['a', 'b', 'c']).intersection(pd.Index(['c', 'd', 'e']))
# ```
#
# __Index.union(other[, sort])__
#
# ```
# pd.Index(['a', 'b', 'c']).union(pd.Index(['c', 'd', 'e']))
# ```
#
# __Index.difference(other[, sort])__
#
# ```
# pd.Index(['a', 'b', 'c']).difference(pd.Index(['c', 'd', 'e']))
# ```
#
# __Index.symmetric_difference(other[, ...])__
#
# ```
# pd.Index(['a', 'b', 'c']).symmetric_difference(pd.Index(['c', 'd', 'e']))
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Selecting</h1>
#
# __Index.asof(label)__
#
# ```
# pd.Index([1, 2, 3]).asof(2.5)
# ```
#
# __Index.asof_locs(where, mask)__
#
# ```
# pd.Index([1, 2, 3]).asof_locs([2.5, 3])
# ```
#
# __Index.get_indexer(target[, method, limit, ...])__
#
# ```
# pd.Index(['a', 'b', 'c']).get_indexer(['c', 'd'])
# ```
#
# __Index.get_indexer_for(target)__
#
# ```
# pd.Index(['a', 'b', 'c']).get_indexer_for(pd.Index(['c', 'd', 'e']))
# ```
#
# __Index.get_indexer_non_unique(target)__
#
# ```
# pd.Index(['a', 'b', 'c']).get_indexer_non_unique(['c', 'd', 'e'])
# ```
#
# __Index.get_level_values(level)__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (2, 'b'), (3, 'c')]).get_level_values(1)
# ```
#
# __Index.get_loc(key)__
#
# ```
# pd.Index(['a', 'b', 'c']).get_loc('c')
# ```
#
# __Index.get_slice_bound(label, side)__
#
# ```
# pd.Index(['a', 'b', 'c']).get_slice_bound('b', 'left')
# ```
#
# __Index.isin(values[, level])__
#
# ```
# pd.Index(['a', 'b', 'c']).isin(['c', 'd'])
# ```
#
# __Index.slice_indexer([start, end, step])__
#
# ```
# pd.Index(['a', 'b', 'c']).slice_indexer(0, 2)
# ```
#
# __Index.slice_locs([start, end, step])__
#
# ```
# pd.Index(['a', 'b', 'c']).slice_locs(start='a', end='b')
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Numeric Index</h1>
#
# __RangeIndex([start, stop, step, dtype, copy, ...])__
#
# ```
# pd.RangeIndex(start=0, stop=10, step=2)
# ```
#
# __RangeIndex.start__
#
# ```
# pd.RangeIndex(start=0, stop=10, step=2).start
# ```
#
# __RangeIndex.stop__
#
# ```
# pd.RangeIndex(start=0, stop=10, step=2).stop
# ```
#
# __RangeIndex.step__
#
# ```
# pd.RangeIndex(start=0, stop=10, step=2).step
# ```
#
# __RangeIndex.from_range(data[, name, dtype])__
#
# ```
# pd.RangeIndex.from_range(range(0, 10, 2))
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">CategoricalIndex</h1>
#
# __CategoricalIndex([data, categories, ...])__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True)
# ```
#
# __CategoricalIndex.codes__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).codes
# ```
#
# __CategoricalIndex.categories__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).categories
# ```
#
# __CategoricalIndex.ordered__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).ordered
# ```
#
# __CategoricalIndex.rename_categories(*args, ...)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).rename_categories(['C', 'B', 'A'])
# ```
#
# __CategoricalIndex.reorder_categories(*args, ...)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).reorder_categories(['C', 'B', 'A'])
# ```
#
# __CategoricalIndex.add_categories(*args, **kwargs)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).add_categories(['d', 'e'])
# ```
#
# __CategoricalIndex.remove_categories(*args, ...)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).remove_categories(['b'])
# ```
#
# __CategoricalIndex.remove_unused_categories(...)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).remove_unused_categories()
# ```
#
# __CategoricalIndex.set_categories(*args, **kwargs)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).set_categories(['C', 'B', 'A'])
# ```
#
# __CategoricalIndex.as_ordered(*args, **kwargs)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=False).as_ordered()
# ```
#
# __CategoricalIndex.as_unordered(*args, **kwargs)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).as_unordered()
# ```
#
# __CategoricalIndex.map(mapper)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).map({'a': 1, 'b': 2, 'c': 3})
# ```
#
# __CategoricalIndex.equals(other)__
#
# ```
# pd.CategoricalIndex(['a', 'b', 'c'], categories=['c', 'b', 'a'], ordered=True).equals(pd.CategoricalIndex(['c', 'b', 'a'], categories=['c', 'b', 'a'], ordered=True))
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">IntervalIndex</h1>
#
# __IntervalIndex(data[, closed, dtype, copy, ...])__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)])
# ```
#
# __IntervalIndex.from_arrays(left, right[, ...])__
#
# ```
# pd.IntervalIndex.from_arrays([0, 1, 2], [1, 2, 3])
# ```
#
# __IntervalIndex.from_tuples(data[, closed, ...])__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)])
# ```
#
# __IntervalIndex.from_breaks(breaks[, closed, ...])__
#
# ```
# pd.IntervalIndex.from_breaks([0, 1, 2, 3])
# ```
#
# __IntervalIndex.left__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).left
# ```
#
# __IntervalIndex.right__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).right
# ```
#
# __IntervalIndex.mid__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).mid
# ```
#
# __IntervalIndex.closed__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).closed
# ```
#
# __IntervalIndex.length__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).length
# ```
#
# __IntervalIndex.values__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).values
# ```
#
# __IntervalIndex.is_empty__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).is_empty
# ```
#
# __IntervalIndex.is_non_overlapping_monotonic__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).is_non_overlapping_monotonic
# ```
#
# __IntervalIndex.is_overlapping__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).is_overlapping
# ```
#
# __IntervalIndex.get_loc(key)__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).get_loc(1)
# ```
#
# __IntervalIndex.get_indexer(target[, method, ...])__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).get_indexer(pd.IntervalIndex.from_tuples([(1, 3)]))
# ```
#
# __IntervalIndex.set_closed(*args, **kwargs)__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).set_closed(left=None, right=None)
# ```
#
# __IntervalIndex.contains(*args, **kwargs)__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).contains([0.5, 1.5, 2.5])
# ```
#
# __IntervalIndex.overlaps(*args, **kwargs)__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).overlaps(pd.IntervalIndex.from_tuples([(1, 3)]))
# ```
#
# __IntervalIndex.to_tuples(*args, **kwargs)__
#
# ```
# pd.IntervalIndex.from_tuples([(0, 1), (1, 2), (2, 3)]).to_tuples()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">MultiIndex</h1>
#
#
# __IndexSlice__
#
# ```
# idx = pd.IndexSlice
# ```
#
# __MultiIndex([levels, codes, sortorder, ...])__
#
# ```
# pd.MultiIndex(levels=[[1, 2], ['a', 'b']], codes=[[0, 0, 1, 1], [0, 1, 0, 1]])
# ```
#
# __MultiIndex.from_arrays(arrays[, sortorder, ...])__
#
# ```
# pd.MultiIndex.from_arrays([[1, 1, 2, 2], ['a', 'b', 'a', 'b']])
# ```
#
# __MultiIndex.from_tuples(tuples[, sortorder, ...])__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')])
# ```
#
# __MultiIndex.from_product(iterables[, ...])__
#
# ```
# pd.MultiIndex.from_product([[1, 2], ['a', 'b']])
# ```
#
# __MultiIndex.from_frame(df[, sortorder, names])__
#
# ```
# df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': ['a', 'b', 'a', 'b']})
# pd.MultiIndex.from_frame(df)
# ```
#
# # - Properties
#
# __MultiIndex.names__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).names
# ```
#
# __MultiIndex.levels__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).levels
# ```
#
# __MultiIndex.codes__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).codes
# ```
#
# __MultiIndex.nlevels__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).nlevels
# ```
#
# __MultiIndex.levshape__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).levshape
# ```
#
# __MultiIndex.dtypes__
#
# ```
# pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char']).dtypes
# ```
#
# # - Components
#
#
# __MultiIndex.set_levels(levels, *[, level, ...])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.set_levels(['one', 'two'], level=0)
# ```
#
# __MultiIndex.set_codes(codes, *[, level, ...])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.set_codes([0, 0, 1, 1], level=0)
# ```
#
# __MultiIndex.to_flat_index()__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.to_flat_index()
# ```
#
# __MultiIndex.to_frame([index, name, ...])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.to_frame(index=False)
# ```
#
# __MultiIndex.sortlevel([level, ascending, ...])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.sortlevel(level=1, ascending=False)
# ```
#
# __MultiIndex.droplevel([level])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.droplevel(level=0)
# ```
#
# __MultiIndex.swaplevel([i, j])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.swaplevel(0, 1)
# ```
#
# __MultiIndex.reorder_levels(order)__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.reorder_levels([1, 0])
# ```
#
# __MultiIndex.remove_unused_levels()__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.remove_unused_levels()
# ```
#
# __MultiIndex.drop(codes[, level, errors])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.drop([0, 2], level=0)
# ```
#
# __MultiIndex.copy([names, deep, name])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.copy()
# ```
#
# __MultiIndex.append(other)__
#
# ```
# idx1 = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b')], names=['num', 'char'])
# idx2 = pd.MultiIndex.from_tuples([(2, 'a'), (2, 'b')], names=['num', 'char'])
# idx1.append(idx2)
# ```
#
# __MultiIndex.truncate([before, after])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.truncate(before=('1', 'b'))
# ```
#
# # - Selecting
#
# __MultiIndex.get_loc(key)__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.get_loc((1, 'a'))
# ```
#
# __MultiIndex.get_locs(seq)__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.get_locs([(1, 'a'), (2, 'b')])
# ```
#
# __MultiIndex.get_loc_level(key[, level, ...])__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.get_loc_level('a', level='char')
# ```
#
# __MultiIndex.get_indexer(target[, method, ...])__
#
# ```
# idx1 = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b')], names=['num', 'char'])
# idx2 = pd.MultiIndex.from_tuples([(1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx2.get_indexer(idx1)
# ```
#
# __MultiIndex.get_level_values(level)__
#
# ```
# idx = pd.MultiIndex.from_tuples([(1, 'a'), (1, 'b'), (2, 'a'), (2, 'b')], names=['num', 'char'])
# idx.get_level_values('num')
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">DatetimeIndex</h1>
#
# __DatetimeIndex([data, freq, tz, normalize, ...])__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10')
# ```
#
# # - Components
#
# __DatetimeIndex.year__
#
# ```
# pd.to_datetime(['2022-01-01', '2023-01-01']).year
# ```
#
# __DatetimeIndex.month__
#
# ```
# pd.to_datetime(['2022-01-01', '2023-01-01']).month
# ```
#
# __DatetimeIndex.day__
#
# ```
# pd.to_datetime(['2022-01-01', '2023-01-01']).day
# ```
#
# __DatetimeIndex.hour__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00']).hour
# ```
#
# __DatetimeIndex.minute__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00']).minute
# ```
#
# __DatetimeIndex.second__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00']).second
# ```
#
# __DatetimeIndex.microsecond__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00.123456', '2023-01-01 15:30:00.789012']).microsecond
# ```
#
# __DatetimeIndex.nanosecond__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00.123456789', '2023-01-01 15:30:00.789012345']).nanosecond
# ```
#
# __DatetimeIndex.date__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00']).date
# ```
#
# __DatetimeIndex.time__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00']).time
# ```
#
# __DatetimeIndex.timetz__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2023-01-01 15:30:00'], tz='US/Pacific').timetz
# ```
#
# __DatetimeIndex.dayofyear__
#
# ```
# pd.to_datetime(['2022-01-01', '2023-01-01']).dayofyear
# ```
#
# __DatetimeIndex.day_of_year__
#
# ```
# pd.to_datetime(['2022-01-01', '2023-01-01']).day_of_year
# ```
#
# __DatetimeIndex.dayofweek__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-01-03']).dayofweek
# ```
#
# __DatetimeIndex.day_of_week__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-01-03']).day_of_week
# ```
#
# __DatetimeIndex.weekday__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-01-03']).weekday
# ```
#
# __DatetimeIndex.quarter__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-04-01']).quarter
# ```
#
# __DatetimeIndex.tz__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', tz='US/Pacific').tz
# ```
#
# __DatetimeIndex.freq__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='D').freq
# ```
#
# __DatetimeIndex.freqstr__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='D').freqstr
# ```
#
# __DatetimeIndex.is_month_start__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').is_month_start
# ```
#
# __DatetimeIndex.is_month_end__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').is_month_end
# ```
#
# __DatetimeIndex.is_quarter_start__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='Q').is_quarter_start
# ```
#
# __DatetimeIndex.is_quarter_end__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='Q').is_quarter_end
# ```
#
# __DatetimeIndex.is_year_start__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').is_year_start
# ```
#
# __DatetimeIndex.is_year_end__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-12-31').is_year_end
# ```
#
# __DatetimeIndex.is_leap_year__
#
# ```
# pd.date_range(start='2022-01-01', end='2025-01-01').is_leap_year
# ```
#
# __DatetimeIndex.inferred_freq__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='D').inferred_freq
# ```
# # - Selecting
#
# __DatetimeIndex.indexer_at_time(time[, asof])__
#
# ```
# idx = pd.date_range(start='2022-01-01', end='2022-01-10', freq='H')
# idx.indexer_at_time('12:00')
# ```
#
# __DatetimeIndex.indexer_between_time(...[, ...])__
#
# ```
# idx = pd.date_range(start='2022-01-01', end='2022-01-10', freq='H')
# idx.indexer_between_time('9:00', '14:00')
# ```
#
# # - Time-specific Operations
#
# __DatetimeIndex.normalize(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01 12:00:00', '2022-01-01 12:30:00']).normalize()
# ```
#
# __DatetimeIndex.strftime(date_format)__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-01-02']).strftime('%Y-%m-%d')
# ```
#
# __DatetimeIndex.snap([freq])__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', freq='H').snap('30min')
# ```
#
# __DatetimeIndex.tz_convert(tz)__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10', tz='US/Pacific').tz_convert('UTC')
# ```
#
# __DatetimeIndex.tz_localize(tz[, ambiguous, ...])__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').tz_localize('US/Pacific')
# ```
#
# __DatetimeIndex.round(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01 12:13:14', '2022-01-01 12:14:15']).round('min')
# ```
#
# __DatetimeIndex.floor(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01 12:13:14', '2022-01-01 12:14:15']).floor('min')
# ```
#
# __DatetimeIndex.ceil(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01 12:13:14', '2022-01-01 12:14:15']).ceil('min')
# ```
#
# __DatetimeIndex.month_name(*args, **kwargs)__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-31').month_name()
# ```
#
# __DatetimeIndex.day_name(*args, **kwargs)__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-07').day_name()
# ```
#
# # - Conversion
#
# __DatetimeIndex.as_unit(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-01-02']).as_unit('D')
# ```
#
# __DatetimeIndex.to_period(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-02-01']).to_period('M')
# ```
#
# __DatetimeIndex.to_pydatetime(*args, **kwargs)__
#
# ```
# pd.to_datetime(['2022-01-01', '2022-02-01']).to_pydatetime()
# ```
#
# __DatetimeIndex.to_series([index, name])__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').to_series()
# ```
#
# __DatetimeIndex.to_frame([index, name])__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').to_frame()
# ```
#
# # - Methods
#
# __DatetimeIndex.mean(*[, skipna, axis])__
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').mean()
# ```
#
# __DatetimeIndex.std(*args, **kwargs)__
#
# ```
# pd.date_range(start='2022-01-01', end='2022-01-10').std()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">TimedeltaIndex</h1>
#
# __TimedeltaIndex([data, unit, freq, closed, ...])__
#
# # - Components
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D')
# ```
#
# __TimedeltaIndex.days__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').days
# ```
#
# __TimedeltaIndex.seconds__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').seconds
# ```
#
# __TimedeltaIndex.microseconds__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').microseconds
# ```
#
# __TimedeltaIndex.nanoseconds__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').nanoseconds
# ```
#
# __TimedeltaIndex.components__
#
# ```
# pd.to_timedelta(['1 day', '10 hours', '30 minutes']).components
# ```
#
# __TimedeltaIndex.inferred_freq__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').inferred_freq
# ```
# # - Conversion
#
# __TimedeltaIndex.as_unit(unit)__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').as_unit('h')
# ```
#
# __TimedeltaIndex.to_pytimedelta(*args, **kwargs)__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').to_pytimedelta()
# ```
#
# __TimedeltaIndex.to_series([index, name])__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').to_series()
# ```
#
# __TimedeltaIndex.round(*args, **kwargs)__
#
# ```
# pd.to_timedelta(['1 day 12 hours 30 minutes', '1 day 12 hours 40 minutes']).round('H')
# ```
#
# __TimedeltaIndex.floor(*args, **kwargs)__
#
# ```
# pd.to_timedelta(['1 day 12 hours 30 minutes', '1 day 12 hours 40 minutes']).floor('H')
# ```
#
# __TimedeltaIndex.ceil(*args, **kwargs)__
#
# ```
# pd.to_timedelta(['1 day 12 hours 30 minutes', '1 day 12 hours 40 minutes']).ceil('H')
# ```
#
# __TimedeltaIndex.to_frame([index, name])__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').to_frame()
# ```
#
# # - Methods
#
# __TimedeltaIndex.mean(*[, skipna, axis])__
#
# ```
# pd.timedelta_range(start='1 day', end='10 days', freq='D').mean()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">PeriodIndex</h1>
#
# __PeriodIndex([data, ordinal, freq, dtype, ...])__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='M')
# ```
#
# # - Properties
#
# __PeriodIndex.day__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').day
# ```
#
# __PeriodIndex.dayofweek__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').dayofweek
# ```
#
# __PeriodIndex.day_of_week__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').day_of_week
# ```
#
# __PeriodIndex.dayofyear__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='D').dayofyear
# ```
#
# __PeriodIndex.day_of_year__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='D').day_of_year
# ```
#
# __PeriodIndex.days_in_month__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='M').days_in_month
# ```
#
# __PeriodIndex.daysinmonth__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='M').daysinmonth
# ```
#
# __PeriodIndex.end_time__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').end_time
# ```
#
# __PeriodIndex.freq__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').freq
# ```
#
# __PeriodIndex.freqstr__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').freqstr
# ```
#
# __PeriodIndex.hour__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='H').hour
# ```
#
# __PeriodIndex.is_leap_year__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='Y').is_leap_year
# ```
#
# __PeriodIndex.minute__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='T').minute
# ```
#
# __PeriodIndex.month__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='M').month
# ```
#
# __PeriodIndex.quarter__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='M').quarter
# ```
#
# __PeriodIndex.qyear__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='Q').qyear
# ```
#
# __PeriodIndex.second__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='S').second
# ```
#
# __PeriodIndex.start_time__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').start_time
# ```
#
# __PeriodIndex.week__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').week
# ```
#
# __PeriodIndex.weekday__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').weekday
# ```
#
# __PeriodIndex.weekofyear__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='D').weekofyear
# ```
#
# __PeriodIndex.year__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-12-31', freq='Y').year
# ```
# # - Methods
#
# __PeriodIndex.asfreq([freq, how])__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').asfreq('H', method='pad')
# ```
#
# __PeriodIndex.strftime(*args, **kwargs)__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').strftime('%Y/%m/%d')
# ```
#
# __PeriodIndex.to_timestamp([freq, how])__
#
# ```
# pd.period_range(start='2022-01-01', end='2022-01-10', freq='D').to_timestamp()
# ```
