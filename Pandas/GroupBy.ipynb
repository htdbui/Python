# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Indexing, Iteration</h1>
#
# __DataFrameGroupBy.__iter__()__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# for name, group in grouped:
#     print(f"Group name: {name}")
#     print(f"Group data:\n{group}")
# ```
#
# __SeriesGroupBy.__iter__()__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# for name, group in grouped:
#     print(f"Group name: {name}")
#     print(f"Group data:\n{group}")
# ```
#
# __DataFrameGroupBy.groups__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# print(grouped.groups)
# ```
#
# __SeriesGroupBy.groups__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# print(grouped.groups)
# ```
#
# __DataFrameGroupBy.indices__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# print(grouped.indices)
# ```
#
# __SeriesGroupBy.indices__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# print(grouped.indices)
# ```
#
# __DataFrameGroupBy.get_group(name[, obj])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# print(grouped.get_group('foo'))
# ```
#
# __SeriesGroupBy.get_group(name[, obj])__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# print(grouped.get_group(0))
# ```
#
# __Grouper(\*args, \*\*kwargs)__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
#
# # Group by column 'A' and calculate the mean of column 'C'
# grouped = df.groupby(pd.Grouper(key='A')).mean()
# print(grouped)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Function Application</h1>
#
# __SeriesGroupBy.apply(func, *args, **kwargs)__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# grouped.apply(lambda x: x**2)
# ```
#
# __DataFrameGroupBy.apply(func, *args, **kwargs)__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# grouped.apply(lambda x: x['C'] - x['D'])
# ```
#
# __SeriesGroupBy.agg([func, engine, engine_kwargs])__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# grouped.agg(['sum', 'mean'])
# ```
#
# __DataFrameGroupBy.agg([func, engine, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# grouped.agg(['sum', 'mean'])
# ```
#
# __SeriesGroupBy.aggregate([func, engine, ...])__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# grouped.aggregate(['sum', 'mean'])
# ```
#
# __DataFrameGroupBy.aggregate([func, engine, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# grouped.aggregate(['sum', 'mean'])
# ```
#
# __SeriesGroupBy.transform(func, *args[, ...])__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# grouped.transform(lambda x: x**2)
# ```
#
# __DataFrameGroupBy.transform(func, *args[, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# grouped.transform(lambda x: x['C'] - x['D'])
# ```
#
# __SeriesGroupBy.pipe(func, *args, **kwargs)__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# grouped = s.groupby(s)
# grouped.pipe(lambda x: x**2)
# ```
#
# __DataFrameGroupBy.pipe(func, *args, **kwargs)__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# grouped = df.groupby('A')
# grouped.pipe(lambda x: x['C'] - x['D'])
# ```
#
# __DataFrameGroupBy.filter(func[, dropna])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': np.random.randn(8),
#                    'D': np.random.randn(8)})
# df.groupby('A').filter(lambda x: x['C'].mean() > 0)
#
# ```
# __SeriesGroupBy.filter(func[, dropna])__
#
# ```
# s = pd.Series([0, 1, 0, 2, 0])
# s.groupby(s).filter(lambda x: x.mean() > 0)
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">DataFrame Descriptive Stats</h1>
#
# __DataFrameGroupBy.all([skipna])__
#
# ```
# df = pd.DataFrame({'A': [True, True, False, False],
#                    'B': [True, False, True, False]})
# grouped = df.groupby('A')
# grouped.all()
# ```
#
# __DataFrameGroupBy.any([skipna])__
#
# ```
# df = pd.DataFrame({'A': [True, True, False, False],
#                    'B': [True, False, True, False]})
# grouped = df.groupby('A')
# grouped.any()
# ```
#
# __DataFrameGroupBy.bfill([limit])__
#
# ```
# df = pd.DataFrame({'A': [1, 2, np.nan, 4, 5],
#                    'B': [6, 7, 8, np.nan, 10],
#                    'C': [11, 12, 13, 14, 15],
#                    'D': [16, np.nan, np.nan, 19, 20],
#                    'E': [21, 22, 23, 24, 25]})
# grouped = df.groupby('A')
# grouped.bfill()
# ```
#
# __DataFrameGroupBy.corr([method, min_periods, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.corr()
# ```
#
# __DataFrameGroupBy.corrwith(other[, axis, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# other = pd.DataFrame({'C': [2, 4, 6, 8, 10, 12, 14, 16],
#                       'D': [1, 3, 5, 7, 9, 11, 13, 15]})
# grouped.corrwith(other)
# ```
#
# __DataFrameGroupBy.count()__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.count()
# ```
#
# __DataFrameGroupBy.cov([min_periods, ddof, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cov()
# ```
#
# __DataFrameGroupBy.cumcount([ascending])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cumcount()
# ```
#
# __DataFrameGroupBy.cummax([axis, numeric_only])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cummax()
# ```
#
# __DataFrameGroupBy.cummin([axis, numeric_only])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cummin()
# ```
#
# __DataFrameGroupBy.cumprod([axis])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cumprod()
# ```
#
# __DataFrameGroupBy.cumsum([axis])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.cumsum()
# ```
#
# __DataFrameGroupBy.describe([percentiles, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.describe()
# ```
#
# __DataFrameGroupBy.diff([periods, axis])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.diff()
# ```
#
# __DataFrameGroupBy.ffill([limit])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, np.nan, 4, 5, np.nan, 7, 8],
#                    'D': [9, 10, 11, np.nan, 13, 14, np.nan, 16]})
# grouped = df.groupby('A')
# grouped.ffill()
# ```
#
# __DataFrameGroupBy.fillna([value, method, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, np.nan, 4, 5, np.nan, 7, 8],
#                    'D': [9, 10, 11, np.nan, 13, 14, np.nan, 16]})
# grouped = df.groupby('A')
# grouped.fillna(0)
# ```
#
# __DataFrameGroupBy.first([numeric_only, min_count])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, np.nan, 4, 5, np.nan, 7, 8],
#                    'D': [9, 10, 11, np.nan, 13, 14, np.nan, 16]})
# grouped = df.groupby('A')
# grouped.first()
# ```
#
# __DataFrameGroupBy.head([n])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.head(2)
# ```
#
#
# __DataFrameGroupBy.idxmax([axis, skipna, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.idxmax()
# ```
#
# __DataFrameGroupBy.idxmin([axis, skipna, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.idxmin()
# ```
#
# __DataFrameGroupBy.last([numeric_only, min_count])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.last()
# ```
#
# __DataFrameGroupBy.max([numeric_only, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.max()
# ```
#
# __DataFrameGroupBy.mean([numeric_only, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.mean()
# ```
#
# __DataFrameGroupBy.median([numeric_only])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.median()
# ```
#
# __DataFrameGroupBy.min([numeric_only, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.min()
# ```
#
#
# __DataFrameGroupBy.ngroup([ascending])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.ngroup()
# ```
#
# __DataFrameGroupBy.nth__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.nth(0)
# ```
#
# __DataFrameGroupBy.nunique([dropna])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, np.nan, 4, 5, np.nan, 7, 8],
#                    'D': [9, 10, 11, np.nan, 13, 14, np.nan, 16]})
# grouped = df.groupby('A')
# grouped.nunique()
# ```
#
# __DataFrameGroupBy.ohlc()__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'two', 'two', 'one', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8]})
# grouped = df.groupby('A')
# grouped.ohlc()
# ```
#
# __DataFrameGroupBy.pct_change([periods, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'two', 'two', 'one', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8]})
# grouped = df.groupby('A')
# grouped.pct_change()
# ```
#
# __DataFrameGroupBy.prod([numeric_only, min_count])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'two', 'two', 'one', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8]})
# grouped = df.groupby('A')
# grouped.prod()
# ```
#
# __DataFrameGroupBy.quantile([q, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar', 'foo', 'foo'],
#                    'B': ['one', 'two', 'two', 'one', 'two', 'two', 'one', 'three'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8]})
# grouped = df.groupby('A')
# grouped.quantile(0.5)
# ```
#
# __DataFrameGroupBy.rank([method, ascending, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.rank()
# ```
#
# __DataFrameGroupBy.resample(rule, *args, **kwargs)__
#
# ```
# idx = pd.date_range('2022-01-01', periods=12, freq='T')
# ts = pd.Series(range(len(idx)), index=idx)
# grouped = ts.groupby(pd.Grouper(freq='5T'))
# grouped.mean()
# ```
#
# __DataFrameGroupBy.rolling(*args, **kwargs)__
#
# ```
# df = pd.DataFrame({'A': [1, 1, 2, 2, 3, 3, 4, 4],
#                    'B': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'C': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.rolling(window=3).mean()
# ```
#
# __DataFrameGroupBy.sample([n, frac, replace, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.sample(n=2)
# ```
#
# __DataFrameGroupBy.sem([ddof, numeric_only])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.sem()
# ```
#
# __DataFrameGroupBy.shift([periods, freq, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.shift(periods=1)
# ```
#
# __DataFrameGroupBy.size()__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.size()
# ```
#
#
# __DataFrameGroupBy.skew([axis, skipna, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.skew()
# ```
#
# __DataFrameGroupBy.std([ddof, engine, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.std()
# ```
#
# __DataFrameGroupBy.sum([numeric_only, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.sum()
# ```
#
# __DataFrameGroupBy.var([ddof, engine, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.var()
# ```
#
# __DataFrameGroupBy.tail([n])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'],
#                    'B': ['one', 'two', 'two', 'one', 'two', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6],
#                    'D': [7, 8, 9, 10, 11, 12]})
# grouped = df.groupby(['A', 'B'])
# grouped.tail(1)
# ```
#
# __DataFrameGroupBy.take(indices[, axis])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby('A')
# grouped.take([1, 3, 5])
# ```
#
# __DataFrameGroupBy.value_counts([subset, ...])__
#
# ```
# df = pd.DataFrame({'A': ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar'],
#                    'B': ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two'],
#                    'C': [1, 2, 3, 4, 5, 6, 7, 8],
#                    'D': [9, 10, 11, 12, 13, 14, 15, 16]})
# grouped = df.groupby(['A', 'B'])
# grouped['C'].value_counts()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Series Descriptive Stats</h1>
#
# __SeriesGroupBy.all([skipna])__
#
# ```
# s = pd.Series([True, True, False, True, False])
# grouped = s.groupby([0, 1, 1, 0, 0])
# grouped.all()
# ```
#
# __SeriesGroupBy.any([skipna])__
#
# ```
# s = pd.Series([True, True, False, True, False])
# grouped = s.groupby([0, 1, 1, 0, 0])
# grouped.any()
# ```
#
# __SeriesGroupBy.bfill([limit])__
#
# ```
# s = pd.Series([1, 2, np.nan, 4, 5, np.nan, 7, 8, np.nan])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.bfill()
# ```
#
# __SeriesGroupBy.corr(other[, method, min_periods])__
#
# ```
# s1 = pd.Series([1, 2, 3, 4, 5])
# s2 = pd.Series([2, 4, 6, 8, 10])
# grouped = s1.groupby([0, 0, 1, 1, 2])
# grouped.corr(s2)
# ```
#
# __SeriesGroupBy.count()__
#
# ```
# s = pd.Series([1, 2, np.nan, 4, 5, np.nan, 7, 8, np.nan])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.count()
# ```
#
# __SeriesGroupBy.cov(other[, min_periods, ddof])__
#
# ```
# s1 = pd.Series([1, 2, 3, 4, 5])
# s2 = pd.Series([2, 4, 6, 8, 10])
# grouped = s1.groupby([0, 0, 1, 1, 2])
# grouped.cov(s2)
# ```
#
# __SeriesGroupBy.cumcount([ascending])__
#
# ```
# s = pd.Series(['a', 'a', 'a', 'b', 'b', 'c'])
# grouped = s.groupby([0, 0, 1, 1, 2, 2])
# grouped.cumcount()
# ```
#
# __SeriesGroupBy.cummax([axis, numeric_only])__
#
# ```
# s = pd.Series([1, 3, 2, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.cummax()
# ```
#
# __SeriesGroupBy.cummin([axis, numeric_only])__
#
# ```
# s = pd.Series([1, 3, 2, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.cummin()
# ```
#
# __SeriesGroupBy.cumprod([axis])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.cumprod()
# ```
#
# __SeriesGroupBy.cumsum([axis])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.cumsum()
# ```
#
# __SeriesGroupBy.describe(\**kwargs)__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.describe()
# ```
#
# __SeriesGroupBy.diff([periods, axis])__
#
# ```
# s = pd.Series([1, 3, 5, 7, 9])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.diff()
# ```
#
# __SeriesGroupBy.ffill([limit])__
#
# ```
# s = pd.Series([1, 2, np.nan, 4, 5, np.nan, 7, 8, np.nan])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.ffill()
# ```
#
# __SeriesGroupBy.fillna([value, method, axis, ...])__
#
# ```
# s = pd.Series([1, 2, np.nan, 4, 5, np.nan, 7, 8, np.nan])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.fillna(method='ffill')
# ```
#
# __SeriesGroupBy.first([numeric_only, min_count])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.first()
# ```
#
# __SeriesGroupBy.head([n])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.head(2)
# ```
#
# __SeriesGroupBy.last([numeric_only, min_count])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.last()
# ```
#
# __SeriesGroupBy.idxmax([axis, skipna])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.idxmax()
# ```
#
# __SeriesGroupBy.idxmin([axis, skipna])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.idxmin()
# ```
#
# __SeriesGroupBy.is_monotonic_increasing__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.is_monotonic_increasing
# ```
#
# __SeriesGroupBy.is_monotonic_decreasing__
#
# ```
# s = pd.Series([5, 4, 3, 2, 1])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.is_monotonic_decreasing
# ```
#
# __SeriesGroupBy.max([numeric_only, min_count, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.max()
# ```
#
# __SeriesGroupBy.mean([numeric_only, engine, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.mean()
# ```
#
# __SeriesGroupBy.median([numeric_only])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.median()
# ```
#
# __SeriesGroupBy.min([numeric_only, min_count, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.min()
# ```
#
# __SeriesGroupBy.ngroup([ascending])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.ngroup()
# ```
#
# __SeriesGroupBy.nlargest([n, keep])__
#
# ```
# s = pd.Series([5, 4, 3, 2, 1])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.nlargest()
# ```
#
# __SeriesGroupBy.nsmallest([n, keep])__
#
# ```
# s = pd.Series([5, 4, 3, 2, 1])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.nsmallest()
# ```
#
# __SeriesGroupBy.nth__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.nth(2)
# ```
#
# __SeriesGroupBy.nunique([dropna])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5, 5, 6])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.nunique()
# ```
#
# __SeriesGroupBy.unique()__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5, 5, 6])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.unique()
# ```
#
# __SeriesGroupBy.ohlc()__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.ohlc()
# ```
#
# __SeriesGroupBy.pct_change([periods, ...])__
#
# ```
# s = pd.Series([1, 2, 4, 8, 16])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.pct_change()
# ```
#
# __SeriesGroupBy.prod([numeric_only, min_count])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.prod()
# ```
#
#
# __SeriesGroupBy.quantile([q, interpolation, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.quantile()
# ```
#
# __SeriesGroupBy.rank([method, ascending, ...])__
#
# ```
# s = pd.Series([5, 4, 3, 2, 1])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.rank()
# ```
#
# __SeriesGroupBy.resample(rule, *args, **kwargs)__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5], index=pd.date_range('2022-01-01', periods=5, freq='D'))
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.resample('W').sum()
# ```
#
# __SeriesGroupBy.rolling(\*args, **kwargs)__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.rolling(window=2).mean()
# ```
#
# __SeriesGroupBy.sample([n, frac, replace, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.sample(frac=0.5)
# ```
#
# __SeriesGroupBy.sem([ddof, numeric_only])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.sem()
# ```
#
# __SeriesGroupBy.shift([periods, freq, axis, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.shift(periods=1)
# ```
#
# __SeriesGroupBy.size()__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.size()
# ```
#
# __SeriesGroupBy.skew([axis, skipna, numeric_only])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.skew()
# ```
#
# __SeriesGroupBy.std([ddof, engine, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.std()
# ```
#
# __SeriesGroupBy.sum([numeric_only, min_count, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.sum()
# ```
#
# __SeriesGroupBy.var([ddof, engine, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.var()
# ```
#
# __SeriesGroupBy.tail([n])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.tail(2)
# ```
#
# __SeriesGroupBy.take(indices[, axis])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.take([0, 1, 2])
# ```
#
# __SeriesGroupBy.value_counts([normalize, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5, 5, 6])
# grouped = s.groupby([0, 0, 1, 1, 2, 2, 2])
# grouped.value_counts()
# ```

# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">Plotting and Visualization</h1>
#
#
# __DataFrameGroupBy.boxplot([subplots, column, ...])__
#
# ```
# df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': [3, 4, 5, 6]})
# grouped = df.groupby('A')
# grouped.boxplot()
# ```
#
# __DataFrameGroupBy.hist([column, by, grid, ...])__
#
# ```
# df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': [3, 4, 5, 6]})
# grouped = df.groupby('A')
# grouped.hist()
# ```
# Here are the code snippets for the remaining `SeriesGroupBy` and `DataFrameGroupBy` methods:
#
# __SeriesGroupBy.hist([by, ax, grid, ...])__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.hist()
# ```
#
# __DataFrameGroupBy.plot__
#
# ```
# df = pd.DataFrame({'A': [1, 1, 2, 2], 'B': [3, 4, 5, 6]})
# grouped = df.groupby('A')
# grouped.plot(x='B', y='A')
# ```
#
# __SeriesGroupBy.plot__
#
# ```
# s = pd.Series([1, 2, 3, 4, 5])
# grouped = s.groupby([0, 0, 1, 1, 2])
# grouped.plot()
# ```
