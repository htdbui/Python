# %% [markdown]
# <h1 style="font-size:60px;font-weight:bold;">String</h1>
#
# __Series.str.capitalize()__
# ```
# pd.Series(['hello world', 'goodbye world']).str.capitalize()
# ```
#
# __Series.str.casefold()__
# ```
# pd.Series(['HelLo WORld', 'GoOdBye WORld']).str.casefold()
# ```
#
# __Series.str.cat([others, sep, na_rep, join])__
# ```
# pd.Series(['a', 'b', 'c']).str.cat(pd.Series(['d', 'e', 'f']), sep='-')
# ```
#
# __Series.str.center(width[, fillchar])__
# ```
# pd.Series(['hello', 'world']).str.center(10, '-')
# ```
#
# __Series.str.contains(pat[, case, flags, na, ...])__
# ```
# pd.Series(['hello', 'world']).str.contains('l')
# ```
#
# __Series.str.count(pat[, flags])__
# ```
# pd.Series(['hello', 'world']).str.count('l')
# ```
#
# __Series.str.decode(encoding[, errors])__
# ```
# pd.Series([b'hello', b'world']).str.decode('utf-8')
# ```
#
# __Series.str.encode(encoding[, errors])__
# ```
# pd.Series(['hello', 'world']).str.encode('utf-8')
# ```
#
# __Series.str.endswith(pat[, na])__
# ```
# pd.Series(['hello', 'world']).str.endswith('d')
# ```
#
# __Series.str.extract(pat[, flags, expand])__
# ```
# pd.Series(['hello 123', 'world 456']).str.extract('(\d+)')
# ```
#
# __Series.str.extractall(pat[, flags])__
# ```
# pd.Series(['hello 123', 'world 456']).str.extractall('(\d+)')
# ```
#
# __Series.str.find(sub[, start, end])__
# ```
# pd.Series(['hello', 'world']).str.find('l')
# ```
#
# __Series.str.findall(pat[, flags])__
# ```
# pd.Series(['hello 123', 'world 456']).str.findall('\d+')
# ```
#
# __Series.str.fullmatch(pat[, case, flags, na])__
# ```
# pd.Series(['hello', 'world']).str.fullmatch('[a-z]{5}')
# ```
#
# __Series.str.get(i)__
# ```
# pd.Series(['hello', 'world']).str.get(1)
# ```
#
# __Series.str.index(sub[, start, end])__
# ```
# pd.Series(['hello', 'world']).str.index('l')
# ```
#
# __Series.str.join(sep)__
# ```
# pd.Series(['hello', 'world']).str.join('-')
# ```
#
# __Series.str.len()__
# ```
# pd.Series(['hello', 'world']).str.len()
# ```
#
# __Series.str.ljust(width[, fillchar])__
# ```
# pd.Series(['hello', 'world']).str.ljust(10, '-')
# ```
#
# __Series.str.lower()__
# ```
# pd.Series(['HELLO', 'WORLD']).str.lower()
# ```
#
# __Series.str.lstrip([to_strip])__
# ```
# pd.Series(['   hello', '   world   ']).str.lstrip()
# ```
#
# __Series.str.match(pat[, case, flags, na])__
# ```
# pd.Series(['hello', 'world']).str.match('[a-z]{5}')
# ```
#
# __Series.str.normalize(form)__
# ```
# pd.Series(['ï', 'é']).str.normalize('NFKD')
# ```
#
# __Series.str.pad(width[, side, fillchar])__
# ```
# pd.Series(['hello', 'world']).str.pad(10, side='right', fillchar='-')
# ```
#
# __Series.str.partition([sep, expand])__
# ```
# pd.Series(['hello world', 'goodbye world']).str.partition(' ')
# ```
#
# __Series.str.removeprefix(prefix)__
# ```
# pd.Series(['hello world', 'goodbye world']).str.removeprefix('hello ')
# ```
#
# __Series.str.removesuffix(suffix)__
# ```
# pd.Series(['hello world', 'goodbye world']).str.removesuffix(' world')
# ```
#
# __Series.str.repeat(repeats)__
# ```
# pd.Series(['hello', 'world']).str.repeat(3)
# ```
#
# __Series.str.replace(pat, repl[, n, case, ...])__
# ```
# pd.Series(['hello', 'world']).str.replace('l', 'x')
# ```
#
# __Series.str.rfind(sub[, start, end])__
# ```
# pd.Series(['hello', 'world']).str.rfind('l')
# ```
#
# __Series.str.rindex(sub[, start, end])__
# ```
# pd.Series(['hello', 'world']).str.rindex('l')
# ```
#
# __Series.str.rjust(width[, fillchar])__
# ```
# pd.Series(['hello', 'world']).str.rjust(10, '-')
# ```
#
# __Series.str.rpartition([sep, expand])__
# ```
# pd.Series(['hello world', 'goodbye world']).str.rpartition(' ')
# ```
#
# __Series.str.rstrip([to_strip])__
# ```
# pd.Series(['   hello', '   world   ']).str.rstrip()
# ```
#
# __Series.str.slice([start, stop, step])__
# ```
# pd.Series(['hello', 'world']).str.slice(start=1, stop=3)
# ```
#
# __Series.str.slice_replace([start, stop, repl])__
# ```
# pd.Series(['hello', 'world']).str.slice_replace(start=1, stop=3, repl='x')
# ```
#
# __Series.str.split([pat, n, expand, regex])__
# ```
# pd.Series(['hello world', 'goodbye world']).str.split(' ')
# ```
#
# __Series.str.rsplit([pat, n, expand])__
# ```
# pd.Series(['hello world', 'goodbye world']).str.rsplit(' ')
# ```
#
# __Series.str.startswith(pat[, na])__
# ```
# pd.Series(['hello', 'world']).str.startswith('h')
# ```
#
# __Series.str.strip([to_strip])__
# ```
# pd.Series(['   hello', '   world   ']).str.strip()
# ```
#
# __Series.str.swapcase()__
# ```
# pd.Series(['HeLlO wOrLd', 'GoOdByE wOrLd']).str.swapcase()
# ```
#
# __Series.str.title()__
# ```
# pd.Series(['the quick brown fox', 'jumped over the lazy dog']).str.title()
# ```
#
# __Series.str.translate(table)__
# ```
# pd.Series(['hello', 'world']).str.translate(str.maketrans('el', 'xy'))
# ```
#
# Sure, here are the updated one-liners for each method:
#
# __Series.str.upper()__
# ```
# pd.Series(['hello', 'world']).str.upper()
# ```
#
# __Series.str.wrap(width, **kwargs)__
# ```
# pd.Series(['the quick brown fox', 'jumped over the lazy dog']).str.wrap(width=10)
# ```
#
# __Series.str.zfill(width)__
# ```
# pd.Series(['hello', 'world']).str.zfill(10)
# ```
#
# __Series.str.isalnum()__
# ```
# pd.Series(['hello', 'world', '123']).str.isalnum()
# ```
#
# __Series.str.isalpha()__
# ```
# pd.Series(['hello', 'world']).str.isalpha()
# ```
#
# __Series.str.isdigit()__
# ```
# pd.Series(['123', '456']).str.isdigit()
# ```
#
# __Series.str.isspace()__
# ```
# pd.Series([' ', '\n']).str.isspace()
# ```
#
# __Series.str.islower()__
# ```
# pd.Series(['hello', 'world']).str.islower()
# ```
#
# __Series.str.isupper()__
# ```
# pd.Series(['HELLO', 'WORLD']).str.isupper()
# ```
#
# __Series.str.istitle()__
# ```
# pd.Series(['The Quick Brown Fox', 'Jumped Over The Lazy Dog']).str.istitle()
# ```
#
# __Series.str.isnumeric()__
# ```
# pd.Series(['123', '456']).str.isnumeric()
# ```
#
# __Series.str.isdecimal()__
# ```
# pd.Series(['123', '456']).str.isdecimal()
# ```
#
# __Series.str.get_dummies([sep])__
# ```
# pd.Series(['hello world', 'goodbye world']).str.get_dummies()
# ```
